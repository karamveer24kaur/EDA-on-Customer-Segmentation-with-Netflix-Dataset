# %%
import pandas as pd # for uploading and storing data
import numpy as np # for doing numerical analysis on the data
import matplotlib.pyplot as plt # for visualisation
import seaborn as sns # for visualization

# %%
# loading the dataset
# for this step, we use pandas library

# Load your data from the CSV file
file_path = r"C:\Users\karam\Documents\python\Projects\Data\netflix_customers.csv" # copy paste the path to csv
df = pd.read_csv(file_path) # read the csv file and store it in a dataframe

# %%
df
# Out:
#                                customer_id  age  gender subscription_type  \
# 0     a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1     49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2     4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3     d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4     4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
# ...                                    ...  ...     ...               ...
# 4995  44f3ba44-b95d-4e50-a786-bac4d06f4a43   19  Female             Basic
# 4996  18779bcb-ba2b-41da-b751-e70b812061ec   67  Female             Basic
# 4997  3f32e8c5-615b-4a3b-a864-db2688f7834f   66    Male          Standard
# 4998  7b0ad82d-6571-430e-90f4-906259e0e89c   59  Female             Basic
# 4999  82aeef39-ddb0-40ad-bae1-5c436e0cf042   57    Male             Basic
#
#       watch_hours  last_login_days         region   device  monthly_fee  \
# ...

# %%
df.head()
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee payment_method  \
# 0        14.73               29   Africa      TV         8.99      Gift Card
# 1         0.70               19   Europe  Mobile        13.99      Gift Card
# 2        16.32               10     Asia      TV        13.99         Crypto
# 3         4.51               12  Oceania      TV        17.99         Crypto
# 4         1.89               13   Africa  Mobile        13.99         Crypto
#
#    number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
df.tail()
# Out:
#                                customer_id  age  gender subscription_type  \
# 4995  44f3ba44-b95d-4e50-a786-bac4d06f4a43   19  Female             Basic
# 4996  18779bcb-ba2b-41da-b751-e70b812061ec   67  Female             Basic
# 4997  3f32e8c5-615b-4a3b-a864-db2688f7834f   66    Male          Standard
# 4998  7b0ad82d-6571-430e-90f4-906259e0e89c   59  Female             Basic
# 4999  82aeef39-ddb0-40ad-bae1-5c436e0cf042   57    Male             Basic
#
#       watch_hours  last_login_days         region   device  monthly_fee  \
# 4995        49.17               11         Europe  Desktop         8.99
# 4996         9.24                2  North America  Desktop         8.99
# 4997        16.55               49  South America  Desktop        13.99
# 4998         9.12                3         Europe   Laptop         8.99
# 4999         1.62               17         Africa   Mobile         8.99
#
#      payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             5000 non-null   object
#  1   age                     5000 non-null   int64
#  2   gender                  5000 non-null   object
#  3   subscription_type       5000 non-null   object
#  4   watch_hours             5000 non-null   float64
#  5   last_login_days         5000 non-null   int64
#  6   region                  5000 non-null   object
#  7   device                  5000 non-null   object
#  8   monthly_fee             5000 non-null   float64
#  9   payment_method          5000 non-null   object
#  10  number_of_profiles      5000 non-null   int64
#  11  avg_watch_time_per_day  5000 non-null   float64
#  12  favorite_genre          5000 non-null   object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 507.9+ KB

# %%
df.describe()
# Out:
#                age  watch_hours  last_login_days  monthly_fee  \
# count  5000.000000  5000.000000      5000.000000  5000.000000
# mean     43.847400    11.649450        30.089800    13.683400
# std      15.501128    12.014654        17.536078     3.692062
# min      18.000000     0.010000         0.000000     8.990000
# 25%      30.000000     3.337500        15.000000     8.990000
# 50%      44.000000     8.000000        30.000000    13.990000
# 75%      58.000000    16.030000        45.000000    17.990000
# max      70.000000   110.400000        60.000000    17.990000
#
#        number_of_profiles  avg_watch_time_per_day
# count         5000.000000             5000.000000
# mean             3.024400                0.874800
# std              1.415841                2.619824
# min              1.000000                0.000000
# 25%              2.000000                0.110000
# 50%              3.000000                0.290000
# 75%              4.000000                0.720000
# ...

# %%
df.isnull().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %%
# Check the shape of the dataset
print(f"Dataset shape: {df.shape}")
# Out:
# Dataset shape: (5000, 13)

# %%
# Get unique values and their counts for categorical columns
for column in ['gender', 'subscription_type', 'region', 'device', 'payment_method', 'favorite_genre']:
    print(df[column].value_counts(), "\n")
# Out:
# gender
# Female    1711
# Male      1654
# Other     1635
# Name: count, dtype: int64
#
# subscription_type
# Premium     1693
# Basic       1661
# Standard    1646
# Name: count, dtype: int64
#
# region
# South America    873
# Europe           867
# North America    851
# Asia             841
# Africa           803
# Oceania          765
# Name: count, dtype: int64
#
# device
# Tablet     1048
# Laptop     1006
# Mobile     1004
# TV          993
# Desktop     949
# Name: count, dtype: int64
#
# payment_method
# Debit Card     1030
# PayPal         1026
# Crypto          995
# Gift Card       976
# Credit Card     973
# Name: count, dtype: int64
#
# favorite_genre
# Drama          731
# Documentary    729
# Romance        725
# Sci-Fi         720
# Horror         713
# Action         697
# Comedy         685
# Name: count, dtype: int64

# %%
# Data Visualization

# to ignore the future warnings
import warnings 
warnings.filterwarnings("ignore")

# %%
# Visualize the distribution of age of customers

# make a figure
plt.figure(figsize=(10, 6))

# add the type of plot, histplot categorises diferent age groups, bins define the no. of categories
ax = sns.histplot(df['age'], bins=20, color = 'pink')

# Get the bin heights and edges, to know how many counts of value are in each bin
heights, edges = np.histogram(df['age'], bins=20, )

# Add text annotations for each bin
for height, edge in zip(heights, edges):
    
    # Calculate the position for the text
    x = edge + (edges[1] - edges[0]) / 2  # Center of the bin
    y = height
    
    # Add the text annotation
    ax.text(x, y, str(height), ha='center', va='bottom')

plt.title('Age Distribution of Netflix Customers')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %%
# insights

# The chart showcases the frequency of Netflix customers across various age groups from 20 to 70 years

# key age groups
# 20s (Age 20-29): Highest frequency with values around 298 to 299 shows  strong engagement among younger audiences
# 30s (Age 30-39): slight decline
# 40s (Age 40-49): further decline
# 50s (Age 50-59): a small rise in frequencies
# 60s (Age 60-69): The highest frequency peaks at 309, suggest srting engagement from older adults

# %%
# visualize subscription type distribution

plt.figure(figsize=(10, 6))
plot = sns.countplot(data=df, x='subscription_type', palette='viridis')

# Add labels to each bar
for p in plt.gca().patches: # loops through each bar(patch) in the current axes (gca stands for "get current axes")
    plt.annotate(f'{int(p.get_height())}', 
                 (p.get_x() + p.get_width() / 2., p.get_height()), 
                 ha='center', va='bottom', 
                 fontsize=12)
    
# annotate function : plt.annnotate
# parameters
# 1.) {int(p.get_height())} = gets height of each bar and converts it into an integer
# 2.) (p.get_x() + p.get_width() / 2., = gives x- cordinate for label so that it is in center 
# p.get_height()) = the y cordinate, set to the top of the bar
# 3.) ha='center', va='bottom' = horizontal alignment to center the text and vertical one to put text just above the bar
# 4.) fontsize=12 = sets font size of text

plt.title('Distribution of Subscription Types')
plt.xlabel('Subscription Type')
plt.ylabel('Count')

plt.show()

# %%
# insights

# subscription counts for all three categories (Basic, Standard, Premium) are relatively similar
# there is no clear dominant subscription type
# customers are equally satisfied with all three offerings

# %%
# visualize average watch time per day by subscription type

plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='subscription_type', y='avg_watch_time_per_day', palette='viridis')

plt.title('Average Watch Time per Day by Subscription Type')
plt.xlabel('Subscription Type')
plt.ylabel('Average Watch Time (hours)')

plt.show()

# %%
# insights

# highest average watch time, approximately 0.9 hours per day, with basic subscription
# Basic subscription is highly engaged despite having fewer content choices
# premium subscription has the lowest average watch time
# it suggest that users with premium access might be diversifying their viewing across more platforms or content types

# %%
# visualize the average monthly fee by region

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='region', y='monthly_fee', palette='Purples')

plt.title('Monthly Fee Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Monthly Fee')
plt.xticks(rotation=45) # used to set the properties of the ticks on the x-axis, rotates the x-axis labels by 45 degrees
# the rotation helps in improving the readability of the labels 
# especially when the labels are long or there are many categories on the x-axis
# rotating them can prevent overlap and make them easier to read

plt.show()

# %%
# insights

# uniformly stacked bars, indicating a consistent fee structure across different regions
# Africa, Europe, Asia, and Oceania show similar monthly fees, with slight variations in color suggest minor differences
# North America displays a darker shade, potentially signaling either a higher monthly fee in comparison

# %%
# visualize numeric data with correlation plot

# get only numeric data, since correlation can be made between numerical values only
numeric_df = df.select_dtypes(include=['number'])

# %%
numeric_df
# Out:
#       age  watch_hours  last_login_days  monthly_fee  number_of_profiles  \
# 0      51        14.73               29         8.99                   1
# 1      47         0.70               19        13.99                   5
# 2      27        16.32               10        13.99                   2
# 3      53         4.51               12        17.99                   2
# 4      56         1.89               13        13.99                   2
# ...   ...          ...              ...          ...                 ...
# 4995   19        49.17               11         8.99                   4
# 4996   67         9.24                2         8.99                   3
# 4997   66        16.55               49        13.99                   2
# 4998   59         9.12                3         8.99                   4
# 4999   57         1.62               17         8.99                   2
#
#       avg_watch_time_per_day
# 0                       0.49
# 1                       0.03
# ...

# %%
# Define groups of features, since a lot of numeric data plotted on correlation plot won't give any actual insight

group1 = ['age', 'watch_hours']
group2 = ['last_login_days', 'monthly_fee']
group3 = ['number_of_profiles', 'avg_watch_time_per_day']

# %%
# Create a new DataFrame with reordered columns

ordered_columns = group1 + group2 + group3
correlation_matrix = numeric_df[ordered_columns].corr()

# %%
# Plot the heatmap

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", 
            cbar_kws={'label': 'Correlation Coefficient'}, square=True)

# parameters
# "annot = True" : enables annotation of each cell with the numeric value representing the correlation coefficient
# "Effect" : You will see numerical values displayed inside each cell of the heatmap
# "cmap='coolwarm'" : specifies colormap used
# "fmt=".2f"" : defines the format for displaying the numerical values in the cells
# "cbar_kws={'label': 'Correlation Coefficient'}" : customizes the color bar displayed next to the heatmap
# "square=True" : forces each cell of the heatmap to be square-shaped

plt.title('Correlation Matrix of Numeric Data')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# insights

# interpreting the Correlation Values
# Values close to 1: Strong positive correlation
# Values close to -1: Strong negative correlation
# Values around 0: No correlation

# 1.) age and watch hours, correlation: 0.03, very weak positive correlation
# indicating age has little effect on watch hours

# 2.) watch hours and average watch time per day, correlation: 0.35, moderate positive correlation
# suggesting that as watch hours increase, the average watch time per day also tends to increase

# 3.) last login days and average watch time per day, correlation: -0.34, moderate negative correlation
# indicating that as the number of days since the last login increases, the average watch time per day tends to decrease

# 4.) monthly fee and other variables
# correlations with other variables (including age, watch hours, and average watch time per day) show negligible values
# suggesting that the monthly fee does not significantly correlate with user activity metrics

# 5.) number of profiles and other variables, correlation values (mostly around 0.02) suggest very weak relationships
# indicating the number of profiles has little to no correlation with other metrics.
